# %% [markdown]
# <a href="https://colab.research.google.com/github/oPeeedro/Desenvolvimento-Web/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sqlalchemy import true
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

base = pd.read_csv('./realtor-data.csv')
base = base.drop(columns=["status", "city", "prev_sold_date", "state", "acre_lot","house_size"]).dropna()
# .sort_values(by='bed',ascending=1)
base = base.iloc[0:30000]

display(pd.DataFrame(base))
# Out:
#        bed  bath  zip_code     price
# 0      3.0   2.0     601.0  105000.0
# 1      4.0   2.0     601.0   80000.0
# 2      2.0   1.0     795.0   67000.0
# 3      4.0   2.0     731.0  145000.0
# 4      6.0   2.0     680.0   65000.0
# ...    ...   ...       ...       ...
# 38810  2.0   1.0    1001.0  180000.0
# 38811  2.0   1.0    1013.0  240000.0
# 38812  3.0   2.0    1056.0  299500.0
# 38813  4.0   3.0    1095.0  650000.0
# 38814  3.0   2.0    1020.0  399900.0
#
# [30000 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(base.loc[:, base.columns != 'bed'], base['bed'], random_state=66)
from sklearn.neighbors import KNeighborsRegressor

training_score = []
test_score = []
# try n_neighbors from 1 to 10
neighbors_settings = range(1, 11)
for n_neighbors in neighbors_settings:
 # build the model
 knn = KNeighborsRegressor(n_neighbors=n_neighbors)
 knn.fit(X_train, y_train)
 # record training set score
 training_score.append(knn.score(X_train, y_train))
 # record test set score
 test_score.append(knn.score(X_test, y_test))
plt.plot(neighbors_settings, training_score, label="training score")
plt.plot(neighbors_settings, test_score, label="test score")
plt.ylabel("R²")
plt.xlabel("n_neighbors")
plt.legend()
plt.savefig('knn_compare_model')

knn = KNeighborsRegressor(n_neighbors=10)
knn.fit(X_train, y_train)
k1 = knn.score(X_train, y_train)
k2 = knn.score(X_test, y_test)
print("R² of KNN Regressor on training set: {:.3f}".format(k1))
print("R² of KNN Regressor on test set: {:.3f}".format(k2))
# Out:
# R² of KNN Regressor on training set: 0.755
# R² of KNN Regressor on test set: 0.632

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X_train, y_train)
l1 = linreg.score(X_train, y_train)
l2 = linreg.score(X_test, y_test)
print("R² of Linear Regression on training set: {:.3f}".format(l1))
print("R² of Linear Regression on test set: {:.3f}".format(l2))
# Out:
# R² of Linear Regression on training set: 0.511
# R² of Linear Regression on test set: 0.473

# %%
#-----------------------------------------------------------------

#Árvore de Decisão (Decision Tree Regressor)------------------------------
base_features = [x for i,x in enumerate(base.columns) if i!=8]
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor(random_state=0)
tree.fit(X_train, y_train)
t1 = tree.score(X_train, y_train)
t2 = tree.score(X_test, y_test)
print("R² of Decision Tree Regressor on training set: {:.3f}".format(t1))
print("R² of Decision Tree Regressor on test set: {:.3f}".format(t2))


tree1 = DecisionTreeRegressor(max_depth=3, random_state=0)
tree1.fit(X_train, y_train)
t3 = tree1.score(X_train, y_train)
t4 = tree1.score(X_test, y_test)
print("R² of Decision Tree Regressor on training set: {:.3f}".format(t3))
print("R² of Decision Tree Regressor on test set: {:.3f}".format(t4))
print("Feature importances:\n{}".format(tree1.feature_importances_))

#plotar o grafico
def plot_feature_importances_housing(model):
 plt.figure(figsize=(3,8))
 n_features = 8
 plt.barh(range(n_features), model.feature_importances_, align='center')
 plt.yticks(np.arange(n_features), base_features)
 plt.xlabel("Feature importance")
 plt.ylabel("Feature")
 plt.ylim(-1, n_features)
plot_feature_importances_housing(tree1)
plt.savefig('feature_importance')
#plt.show()
# Out:
# R² of Decision Tree Regressor on training set: 0.992
# R² of Decision Tree Regressor on test set: 0.893
# R² of Decision Tree Regressor on training set: 0.523
# R² of Decision Tree Regressor on test set: 0.478
# Feature importances:
# [0.98418773 0.         0.01581227]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-5e01ce7db8ee> in <cell line: 31>()
#      29  plt.ylabel("Feature")
#      30  plt.ylim(-1, n_features)
# ---> 31 plot_feature_importances_housing(tree1)
#      32 plt.savefig('feature_importance')
#      33 #plt.show()
#
# <ipython-input-9-5e01ce7db8ee> in plot_feature_importances_housing(model)
#      24  plt.figure(figsize=(3,8))
#      25  n_features = 8
# ---> 26  plt.barh(range(n_features), model.feature_importances_, align='center')
#      27  plt.yticks(np.arange(n_features), base_features)
#      28  plt.xlabel("Feature importance")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in barh(y, width, height, left, align, data, **kwargs)
#    2455         y, width, height=0.8, left=None, *, align='center',
#    2456         data=None, **kwargs):
# -> 2457     return gca().barh(
#    2458         y, width, height=height, left=left, align=align,
#    2459         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, data, **kwargs)
#    2647         """
#    2648         kwargs.setdefault('orientation', 'horizontal')
# -> 2649         patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2650                            align=align, data=data, **kwargs)
#    2651         return patches
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2415                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2416
# -> 2417         x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2418             # Make args iterable too.
#    2419             np.atleast_1d(x), height, width, y, linewidth, hatch)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in broadcast_arrays(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     537     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     538
# --> 539     shape = _broadcast_shape(*args)
#     540
#     541     if all(array.shape == shape for array in args):
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     419     # use the old-iterator because np.nditer does not handle size 0 arrays
#     420     # consistently
# --> 421     b = np.broadcast(*args[:32])
#     422     # unfortunately, it cannot handle 32 or more arguments directly
#     423     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 2 with shape (3,) and arg 3 with shape (8,).

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100, random_state=0)
rf.fit(X_train, y_train)
r1 = rf.score(X_train, y_train)
r2 = rf.score(X_test, y_test)
print("R² of Random Forest Regressor on training set: {:.3f}".format(r1))
print("R² of Random Forest Regressor on test set: {:.3f}".format(r2))

rf1 = RandomForestRegressor(max_depth=7, n_estimators=100, random_state=42)
rf1.fit(X_train, y_train)
r3 = rf1.score(X_train, y_train)
r4 = rf1.score(X_test, y_test)
print("R² of Random Forest Regressor on training set: {:.3f}".format(r3))
print("R² of Random Forest Regressor on test set: {:.3f}".format(r4))

plot_feature_importances_housing(rf)
# Out:
# R² of Random Forest Regressor on training set: 0.978
# R² of Random Forest Regressor on test set: 0.948
# R² of Random Forest Regressor on training set: 0.476
# R² of Random Forest Regressor on test set: 0.467
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6156800f5906> in <cell line: 16>()
#      14 print("R² of Random Forest Regressor on test set: {:.3f}".format(r4))
#      15
# ---> 16 plot_feature_importances_housing(rf)
#
# <ipython-input-9-472f220105d0> in plot_feature_importances_housing(model)
#      24  plt.figure(figsize=(8,6))
#      25  n_features = 8
# ---> 26  plt.barh(range(n_features), model.feature_importances_, align='center')
#      27  plt.yticks(np.arange(n_features), base_features)
#      28  plt.xlabel("Feature importance")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in barh(y, width, height, left, align, data, **kwargs)
#    2455         y, width, height=0.8, left=None, *, align='center',
#    2456         data=None, **kwargs):
# -> 2457     return gca().barh(
#    2458         y, width, height=height, left=left, align=align,
#    2459         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, data, **kwargs)
#    2647         """
#    2648         kwargs.setdefault('orientation', 'horizontal')
# -> 2649         patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2650                            align=align, data=data, **kwargs)
#    2651         return patches
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2415                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2416
# -> 2417         x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2418             # Make args iterable too.
#    2419             np.atleast_1d(x), height, width, y, linewidth, hatch)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in broadcast_arrays(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     537     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     538
# --> 539     shape = _broadcast_shape(*args)
#     540
#     541     if all(array.shape == shape for array in args):
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     419     # use the old-iterator because np.nditer does not handle size 0 arrays
#     420     # consistently
# --> 421     b = np.broadcast(*args[:32])
#     422     # unfortunately, it cannot handle 32 or more arguments directly
#     423     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 2 with shape (3,) and arg 3 with shape (8,).

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb = GradientBoostingRegressor(random_state=0)
gb.fit(X_train, y_train)
g1 = gb.score(X_train, y_train)
g2 = gb.score(X_test, y_test)
print("R^2 of Gradient Boosting Regressor on training set: {:.3f}".format(g1))
print("R^2 of Gradient Boosting Regressor on test set: {:.3f}".format(g2))

gb1 = GradientBoostingRegressor(random_state=0, max_depth=4)
gb1.fit(X_train, y_train)
g3 = gb1.score(X_train, y_train)
g4 = gb1.score(X_test, y_test)
print("R² of Gradient Boosting Regressor on training set: {:.3f}".format(g3))
print("R² of Gradient Boosting Regressor on test set: {:.3f}".format(g4))

gb2 = GradientBoostingRegressor(random_state=0, learning_rate=0.15)
gb2.fit(X_train, y_train)
g5 = gb2.score(X_train, y_train)
g6 = gb2.score(X_test, y_test)
print("R² of Gradient Boosting Regressor on training set: {:.3f}".format(g5))
print("R² of Gradient Boosting Regressor on test set: {:.3f}".format(g6))

plot_feature_importances_housing(gb1)
# Out:
# R^2 of Gradient Boosting Regressor on training set: 0.424
# R^2 of Gradient Boosting Regressor on test set: 0.419
# R² of Gradient Boosting Regressor on training set: 0.492
# R² of Gradient Boosting Regressor on test set: 0.480
# R² of Gradient Boosting Regressor on training set: 0.457
# R² of Gradient Boosting Regressor on test set: 0.449
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-45e6221e9737> in <cell line: 24>()
#      22 print("R² of Gradient Boosting Regressor on test set: {:.3f}".format(g6))
#      23
# ---> 24 plot_feature_importances_housing(gb1)
#
# <ipython-input-9-472f220105d0> in plot_feature_importances_housing(model)
#      24  plt.figure(figsize=(8,6))
#      25  n_features = 8
# ---> 26  plt.barh(range(n_features), model.feature_importances_, align='center')
#      27  plt.yticks(np.arange(n_features), base_features)
#      28  plt.xlabel("Feature importance")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in barh(y, width, height, left, align, data, **kwargs)
#    2455         y, width, height=0.8, left=None, *, align='center',
#    2456         data=None, **kwargs):
# -> 2457     return gca().barh(
#    2458         y, width, height=height, left=left, align=align,
#    2459         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, data, **kwargs)
#    2647         """
#    2648         kwargs.setdefault('orientation', 'horizontal')
# -> 2649         patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2650                            align=align, data=data, **kwargs)
#    2651         return patches
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2415                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2416
# -> 2417         x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2418             # Make args iterable too.
#    2419             np.atleast_1d(x), height, width, y, linewidth, hatch)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in broadcast_arrays(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     537     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     538
# --> 539     shape = _broadcast_shape(*args)
#     540
#     541     if all(array.shape == shape for array in args):
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     419     # use the old-iterator because np.nditer does not handle size 0 arrays
#     420     # consistently
# --> 421     b = np.broadcast(*args[:32])
#     422     # unfortunately, it cannot handle 32 or more arguments directly
#     423     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 2 with shape (3,) and arg 3 with shape (8,).

# %%
from sklearn.svm import SVR

svr = SVR()
svr.fit(X_train, y_train)
s1 = svr.score(X_train, y_train)
s2 = svr.score(X_test, y_test)
print("R² of Support Vector Regressor on training set: {:.3f}".format(s1))
print("R² of Support Vector Regressor on test set: {:.3f}".format(s2))

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)
svr1 = SVR()
svr1.fit(X_train_scaled, y_train)
s3 = svr1.score(X_train_scaled, y_train)
s4 = svr1.score(X_test_scaled, y_test)
print("R² of Support Vector Regressor on training set: {:.3f}".format(s3))
print("R² of Support Vector Regressor on test set: {:.3f}".format(s4))

svr2 = SVR(gamma=10)
svr2.fit(X_train_scaled, y_train)
s5 = svr2.score(X_train_scaled, y_train)
s6 = svr2.score(X_test_scaled, y_test)
print("R² of Support Vector Regressor on training set: {:.3f}".format(s5))
print("R² of Support Vector Regressor on test set: {:.3f}".format(s6))
# Out:
# R² of Support Vector Regressor on training set: 0.014
# R² of Support Vector Regressor on test set: 0.005
# R² of Support Vector Regressor on training set: 0.513
# R² of Support Vector Regressor on test set: 0.012
# R² of Support Vector Regressor on training set: 0.466
# R² of Support Vector Regressor on test set: -0.005

# %%
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor(random_state=42)
mlp.fit(X_train, y_train)
m1 = mlp.score(X_train, y_train)
m2 = mlp.score(X_test, y_test)
print("R² of MLP Regressor on training set: {:.3f}".format(m1))
print("R² of MLP Regressor on test set: {:.3f}".format(m2))

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)
mlp1 = MLPRegressor(random_state=0)
mlp1.fit(X_train_scaled, y_train)
m3 = mlp1.score(X_train_scaled, y_train)
m4 = mlp1.score(X_test_scaled, y_test)
print('R² of MLP Regressor on training set: {:.3f}'.format(m3))
print('R² of MLP Regressor on test set: {:.3f}'.format(m4))

mlp2 = MLPRegressor(max_iter=1000, random_state=0)
mlp2.fit(X_train_scaled, y_train)
m5 = mlp2.score(X_train_scaled, y_train)
m6 = mlp2.score(X_test_scaled, y_test)
print("R² of MLP Regressor on training set: {:.3f}".format(m5))
print("R² of MLP Regressor on test set: {:.3f}".format(m6))

mlp3 = MLPRegressor(max_iter=1000, alpha=1, random_state=0)
mlp3.fit(X_train_scaled, y_train)
m7 = mlp3.score(X_train_scaled, y_train)
m8 = mlp3.score(X_test_scaled, y_test)
print("R² of MLP Regressor on training set: {:.3f}".format(m7))
print("R² of MLP Regressor on test set: {:.3f}".format(m8))
# Out:
# R² of MLP Regressor on training set: -418.084
# R² of MLP Regressor on test set: -534.674
# R² of MLP Regressor on training set: 0.561
# R² of MLP Regressor on test set: 0.514
# R² of MLP Regressor on training set: 0.561
# R² of MLP Regressor on test set: 0.514
# R² of MLP Regressor on training set: 0.539
# R² of MLP Regressor on test set: 0.498

# %%
models = ['KNN Regressor', 'Linear Regression', 'Decision Tree Regressor' ,'Random Forest Regressor',
 'Gradient Boosting Regressor','Support Vector Regressor', 'MLP Regressor']
tests_score = [k2, l2, t4, r2, g4, s6, m8]
compare_models = pd.DataFrame({ "Algorithms": models, "Tests Score": tests_score })
compare_models.sort_values(by = "Tests Score", ascending = False)

import matplotlib.pyplot as plt
#matplotlib inline
plt.figure(figsize=(8,8))
sb.barplot(x = "Tests Score", y = "Algorithms", data = compare_models)
plt.show()
